# %%
import auto_grids

# %%
receptor= '../tmp/DRD2/6CM4_protein.pdb'

# %%
targ_atoms_lists, targ_res_lists, s1=auto_grids.get_chains_lists(receptor, 'target')

# %%
targ_atoms_lists
# Out:
# [[<Atom N>,
#   <Atom CA>,
#   <Atom C>,
#   <Atom O>,
#   <Atom CB>,
#   <Atom N>,
#   <Atom CA>,
#   <Atom C>,
#   <Atom O>,
#   <Atom CB>,
#   <Atom N>,
#   <Atom CA>,
#   <Atom C>,
#   <Atom O>,
#   <Atom CB>,
#   <Atom CG>,
#   <Atom CD1>,
#   <Atom CD2>,
#   <Atom CE1>,
#   <Atom CE2>,
#   <Atom CZ>,
#   <Atom OH>,
#   <Atom N>,
#   <Atom CA>,
#   <Atom C>,
#   <Atom O>,
#   <Atom CB>,
#   <Atom N>,
#   <Atom CA>,
#   <Atom C>,
#   <Atom O>,
#   <Atom CB>,
#   <Atom CG2>,
#   <Atom OG1>,
#   <Atom N>,
#   <Atom CA>,
#   <Atom C>,
#   <Atom O>,
#   <Atom CB>,
#   <Atom CG>,
#   <Atom CD1>,
#   <Atom CD2>,
#   <Atom N>,
#   <Atom CA>,
#   <Atom C>,
#   <Atom O>,
#   <Atom CB>,
#   <Atom CG>,
#   <Atom CD1>,
#   <Atom CD2>,
#   <Atom N>,
#   <Atom CA>,
#   <Atom C>,
#   <Atom O>,
#   <Atom CB>,
#   <Atom CG2>,
#   <Atom OG1>,
#   <Atom N>,
#   <Atom CA>,
#   <Atom C>,
#   <Atom O>,
#   <Atom CB>,
#   <Atom N>,
#   <Atom CA>,
#   <Atom C>,
#   <Atom O>,
#   <Atom CB>,
# ...
